# %%
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
from transformers import pipeline
from transformers.utils import logging
logging.set_verbosity(40)

# %%
from IPython.display import Image

# %%
# file 1
#https://drive.google.com/file/d/1hC9IC-VuXu6c5uB1iErYL69uIyjGVSZV/view?usp=drive_link
# !gdown 1hC9IC-VuXu6c5uB1iErYL69uIyjGVSZV
file_name1 = "image1.jpg"

# file 2
#https://drive.google.com/file/d/11WSFvj80JohK6vTscBNLiXm6FU6BFUs7/view?usp=drive_link
# !gdown 11WSFvj80JohK6vTscBNLiXm6FU6BFUs7
file_name2 = "image2.jpg"

# file 3
#https://drive.google.com/file/d/12sFwi0axah5KLLIFylecgdwYZ39p_QUI/view?usp=drive_link
# !gdown 12sFwi0axah5KLLIFylecgdwYZ39p_QUI
file_name3 = "image3.jpg"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1hC9IC-VuXu6c5uB1iErYL69uIyjGVSZV
# To: /content/image3.jpg
# 100% 8.69M/8.69M [00:00<00:00, 86.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=11WSFvj80JohK6vTscBNLiXm6FU6BFUs7
# To: /content/image1.jpg
# 100% 6.88M/6.88M [00:00<00:00, 172MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=12sFwi0axah5KLLIFylecgdwYZ39p_QUI
# To: /content/image2.jpg
# 100% 3.90M/3.90M [00:00<00:00, 143MB/s]

# %%
### Task: Image captioning
captioner = pipeline(task="image-to-text",
                     model="nlpconnect/vit-gpt2-image-captioning")

# %%
captioner2 = pipeline("image-to-text", model="Salesforce/blip-image-captioning-base")

# %%
captioner3 = pipeline("image-to-text", model="microsoft/git-base")
# Out:
# config.json:   0%|          | 0.00/2.82k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/707M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/141 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/453 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/503 [00:00<?, ?B/s]

# %% [markdown]
# **Photo 1**

# %%
display(Image(filename=file_name1))
print(captioner(file_name1))
print(captioner2(file_name1))
print(captioner3(file_name1))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# **Photo 2**

# %%
display(Image(filename=file_name2))
print(captioner(file_name2))
print(captioner2(file_name2))
print(captioner3(file_name2))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# **Photo 3**

# %%
display(Image(filename=file_name3))
print(captioner(file_name3))
print(captioner2(file_name3))
print(captioner3(file_name3))
# Out:
# Output hidden; open in https://colab.research.google.com to view.
